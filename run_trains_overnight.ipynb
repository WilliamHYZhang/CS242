# %%
import os
import sys

# %%
# !python3 train.py --epochs 160 --student resnet110 --cuda 1 --dataset cifar10
# Out:
# Namespace(epochs=160, dataset='cifar10', batch_size=128, learning_rate=0.1, momentum=0.9, weight_decay=0.0001, teacher='', student='resnet110', teacher_checkpoint='', cuda=True, dataset_dir='./data', ta='', ta_checkpoint='')
# /home/sedik/main_venv/lib/python3.12/site-packages/nni/runtime/trial_command_channel/standalone.py:34: RuntimeWarning: Running trial code without runtime. Please check the tutorial if you are new to NNI: https://nni.readthedocs.io/en/stable/tutorials/hpo_quickstart_pytorch/main.html
#   warnings.warn(warning_message, RuntimeWarning)
# ---------- Training Student -------
# Files already downloaded and verified
# Files already downloaded and verified
# epoch 0/160
# {"metric": "resnet110_val_accuracy", "value": 41.32}
# epoch 1/160
# {"metric": "resnet110_val_accuracy", "value": 53.77}
# epoch 2/160
# {"metric": "resnet110_val_accuracy", "value": 60.69}
# epoch 3/160
# {"metric": "resnet110_val_accuracy", "value": 61.48}
# epoch 4/160
# ...

# %%
# !python3 train.py --epochs 60 --teacher resnet110 --teacher-checkpoint ./resnet110_None_best.pth.tar --student resnet20 --cuda 1 --dataset cifar10
# Out:
# Namespace(epochs=160, dataset='cifar10', batch_size=128, learning_rate=0.1, momentum=0.9, weight_decay=0.0001, teacher='resnet110', student='resnet20', teacher_checkpoint='./resnet110_None_best.pth.tar', cuda=True, dataset_dir='./data', ta='', ta_checkpoint='')
# /home/sedik/main_venv/lib/python3.12/site-packages/nni/runtime/trial_command_channel/standalone.py:34: RuntimeWarning: Running trial code without runtime. Please check the tutorial if you are new to NNI: https://nni.readthedocs.io/en/stable/tutorials/hpo_quickstart_pytorch/main.html
#   warnings.warn(warning_message, RuntimeWarning)
# ---------- Loading Teacher -------
# ...

# %%
# !python3 train.py --epochs 160 --teacher resnet110 --teacher-checkpoint ./resnet110_None_best.pth.tar --ta resnet20 --ta-checkpoint resnet20_None_best.pth.tar --student resnet8 --cuda 1 --dataset cifar10
# Out:
# Namespace(epochs=160, dataset='cifar10', batch_size=128, learning_rate=0.1, momentum=0.9, weight_decay=0.0001, teacher='resnet110', student='resnet8', teacher_checkpoint='./resnet110_None_best.pth.tar', cuda=True, dataset_dir='./data', ta='resnet20', ta_checkpoint='resnet20_None_best.pth.tar')
# /home/sedik/main_venv/lib/python3.12/site-packages/nni/runtime/trial_command_channel/standalone.py:34: RuntimeWarning: Running trial code without runtime. Please check the tutorial if you are new to NNI: https://nni.readthedocs.io/en/stable/tutorials/hpo_quickstart_pytorch/main.html
#   warnings.warn(warning_message, RuntimeWarning)
# ---------- Loading Teacher -------
# ...

# %%
# !python3 train.py --epochs 1 --student resnet14 --cuda 1 --dataset cifar10
# Out:
# Namespace(epochs=1, dataset='cifar10', batch_size=128, learning_rate=0.1, momentum=0.9, weight_decay=0.0001, teacher='', student='resnet14', teacher_checkpoint='', cuda=True, dataset_dir='./data', ta='', ta_checkpoint='')
# /home/sedik/main_venv/lib/python3.12/site-packages/nni/runtime/trial_command_channel/standalone.py:34: RuntimeWarning: Running trial code without runtime. Please check the tutorial if you are new to NNI: https://nni.readthedocs.io/en/stable/tutorials/hpo_quickstart_pytorch/main.html
#   warnings.warn(warning_message, RuntimeWarning)
# ResNet_Cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
from resnet_cifar import *

# %%
resnet110_cifar()
# Out:
# ResNet_Cifar(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
# ...
